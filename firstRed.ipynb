# %% [markdown]
# <a href="https://colab.research.google.com/github/ErolesSA/Argentina-Programa---Python/blob/main/firstRed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Tu primera red neuronal en Python y Tensorflow

# %%
import tensorflow as tf
import numpy as np

# %%
celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

# %%
capa = tf.keras.layers.Dense(units=1, input_shape=[1])
modelo = tf.keras.Sequential([capa])

# %%
modelo.compile(
    optimizer = tf.keras.optimizers.Adam(0.1),
    loss = 'mean_squared_error'
)

# %%
print("Comenzando entrenamiento...")
historial = modelo.fit(celsius, fahrenheit, epochs=1000, verbose=False)
print("¡Modelo entrenado!")
# Out:
# Comenzando entrenamiento...
# ¡Modelo entrenado!

# %%
import matplotlib.pyplot as plt

plt.xlabel("# Epoca")
plt.ylabel("Magnitud de perdida")
plt.plot(historial.history["loss"])

# %%
print("¡Hagamos una predicción!")
resultado = modelo.predict(np.array([150.0]))  # Convertir la lista en un array NumPy
print("¡El resultado es " + str(resultado) + " grados Fahrenheit!")
# Out:
# ¡Hagamos una predicción!
# 1/1 [==============================] - 0s 124ms/step
# ¡El resultado es [[301.65323]] grados Fahrenheit!
